# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import json
import re

# %%
def visualFromFile():
    file_path = './'
    file_name = 'SES.TXT'
    
    path_name = file_path + file_name
    with open(path_name, newline='') as some_file:
        file_data = some_file.read()
#         print(file_data)
        regex = r"{.*?}"

#         test_str = "{sadad;:\",.23123  asd},{s.231adad;:\",23  asd}{dsdsd}"

#         matches = re.finditer(regex, test_str, re.MULTILINE)

        matches = re.finditer(regex, file_data, re.MULTILINE)
        jsons_data = []
    
        for matchNum, match in enumerate(matches, start=1):
            converted_json = json.loads(match.group())
            print(converted_json)
            
#             jsons_data.append()

#             print ("Match {matchNum} was found at {start}-{end}: {match}".format(
#                 matchNum = matchNum, start = match.start(), end = match.end(), match = match.group()))
            print('matchNum', matchNum)
#             print('match', match.group())
            
            
        
#             for groupNum in range(0, len(match.groups())):
#                 groupNum = groupNum + 1

#                 print ("Group {groupNum} found at {start}-{end}: {group}".format(
#                     groupNum = groupNum, start = match.start(groupNum), 
#                     end = match.end(groupNum), group = match.group(groupNum)))


#         myjson = json.load(some_file)

        
    return 0

visualFromFile()

    
# def loadDataFromFile( pathname ):
#     cnt = []
#     sensorTime =  []
#     ax = []
#     ay = []
#     az = []
#     gx = []
#     gy = []
#     gz = []
#     err = []
#     with open(pathname, newline='') as csvfile:
#         reader = csv.DictReader(csvfile)
#         for row in reader:
#             #print(row);
#             gx.append(row['gx'])
#             gy.append(row['gy'])
#             gz.append(row['gz'])
#             ax.append(row['ax'])
#             ay.append(row['ay'])
#             az.append(row['az'])
            
#             if 'cnt' in row:
#                 cnt.append(row['cnt'])
#                 #print("blah")
#             #else:
#                 #print("boo")
            
#             sensorTime.append(row['sensorTime'])
#             if len(sensorTime) < 2:
#                 err.append(0)
#             else:
#                 err.append((int(sensorTime[len(sensorTime)-2]) - int(sensorTime[len(sensorTime)-1]))*0.000039)

#     gyro_x = go.Scatter(
#         x=sensorTime,
#         y=gx,
#         name='gyro X'
#     )
#     gyro_y = go.Scatter(
#         x=sensorTime,
#         y=gy,
#         name='gyro Y'
#     )
#     gyro_z = go.Scatter(
#         x=sensorTime,
#         y=gz,
#         name='gyro Z'
#     )
#     accel_x = go.Scatter(
#         x=sensorTime,
#         y=ax,
#         name='accel X'
#     )
#     accel_y = go.Scatter(
#         x=sensorTime,
#         y=ay,
#         name='accel Y'
#     )
#     accel_z = go.Scatter(
#         x=sensorTime,
#         y=az,
#         name='accel Z'
#     )
#     relative_error = go.Scatter(
#         x=sensorTime,
#         y=err,
#         name='Error'
#     )
    
#     return [gyro_x, gyro_y, gyro_z, accel_x, accel_y, accel_z,relative_error]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-6c4348becc61> in <module>()
#      42     return 0
#      43
# ---> 44 visualFromFile()
#      45
#      46
#
# <ipython-input-19-6c4348becc61> in visualFromFile()
#      18         for matchNum, match in enumerate(matches, start=1):
#      19             converted_json = json.loads(match.group())
# ---> 20             print(converted_json['glossary']['title'])
#      21
#      22 #             jsons_data.append()
#
# KeyError: 'glossary'
